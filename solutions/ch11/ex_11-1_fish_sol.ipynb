# %% [markdown]
# # Exercise 11-1: Create a multiple regression

# %% [markdown]
# ## Read the data

# %%
import pandas as pd
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
fish = pd.read_csv('../../data/Fish.csv')

# %%
fish.head()
# Out:
#   Species  Weight  Length1  Length2  Length3   Height   Width
# 0   Bream   242.0     23.2     25.4     30.0  11.5200  4.0200
# 1   Bream   290.0     24.0     26.3     31.2  12.4800  4.3056
# 2   Bream   340.0     23.9     26.5     31.1  12.3778  4.6961
# 3   Bream   363.0     26.3     29.0     33.5  12.7300  4.4555
# 4   Bream   430.0     26.5     29.0     34.0  12.4440  5.1340

# %% [markdown]
# ## Clean the data

# %%
fish = fish.rename(columns={'Length1':'VerticalLength', 
                     'Length2':'DiagonalLength', 
                     'Length3':'CrossLength'})

# %% [markdown]
# ## Identify a correlation

# %%
fish_numeric = fish[['Weight','VerticalLength','DiagonalLength','CrossLength','Height','Width']]
fish_numeric.corr()[['Weight']]
# Out:
#                   Weight
# Weight          1.000000
# VerticalLength  0.915712
# DiagonalLength  0.918618
# CrossLength     0.923044
# Height          0.724345
# Width           0.886507

# %%
sns.heatmap(data=fish_numeric.corr(), annot=True, cmap='Blues')
# Out:
# <Axes: >

# %% [markdown]
# ## Create the multiple regression model

# %%
bream = fish.query('Species == "Bream"')

# %%
x_train, x_test, y_train, y_test = train_test_split(
    bream[['Height','Width','VerticalLength']], 
    bream[['Weight']])

# %%
model = LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
model.score(x_test, y_test)
# Out:
# 0.9571569754026528

# %%
y_predicted = model.predict(x_test)
predicted = pd.DataFrame(y_predicted, columns = ['PredictedWeight'])

# %%
final = predicted.join([x_test.reset_index(drop=True), 
                       y_test.reset_index(drop=True)])

# %% [markdown]
# ## Plot the residuals

# %%
final['Residual'] = final.Weight - final.PredictedWeight

# %%
sns.kdeplot(data=final, x='Residual')
# Out:
# <Axes: xlabel='Residual', ylabel='Density'>

# %%
final_melted = final.melt(id_vars=['Height','Width','VerticalLength'], 
                          value_vars=['Weight','PredictedWeight'],
                          var_name='WeightType', value_name='WeightValue')

final_melted2 = final_melted.melt(id_vars=['WeightType','WeightValue'], 
                                  value_vars=['Height','Width','VerticalLength'],
                                  var_name='Dimension', value_name='DimensionValue')

# %%
import matplotlib.pyplot as plt

fig, axes = plt.subplots(1, 3, figsize=(15, 5))

dimensions = ['Height', 'Width', 'VerticalLength']

for i, dimension in enumerate(dimensions):
    dimension_data = final_melted2[final_melted2['Dimension'] == dimension]
    sns.scatterplot(data=dimension_data, x='DimensionValue', y='WeightValue', 
                    hue='WeightType', ax=axes[i])
    axes[i].set_title(f'{dimension} vs Weight')
    axes[i].set_xlabel(dimension)
    axes[i].set_ylabel('Weight Value')

plt.tight_layout()
plt.show()
